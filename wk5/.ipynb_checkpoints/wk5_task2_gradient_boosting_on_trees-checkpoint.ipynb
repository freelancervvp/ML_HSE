# %%
import pandas as pd
import numpy as np
gbm_data_df = pd.read_csv("gbm-data.csv")#, header = None, names = ['y', 'x1', 'x2'])
print(gbm_data_df.shape)
gbm_data_df.head(10)
# Out:
# (3751, 1777)
#    Activity        D1        D2    D3    D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.00  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.00  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.00  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.50  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.00  0.494734  0.781422  0.154361
# 5         0  0.133333  0.771035  0.20  0.25  0.122153  0.677398  0.267224
# 6         1  0.066700  0.567401  0.10  0.00  0.116578  0.689802  0.274886
# 7         1  0.133333  0.610057  0.15  0.00  0.105176  0.759602  0.313393
# 8         1  0.000000  0.776816  0.05  0.00  0.458446  0.738631  0.246347
# 9         0  0.100000  0.768150  0.10  0.25  0.262299  0.598972  0.377065
#
#          D8        D9  ...    D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# ...

# %%
gbm_data = gbm_data_df.values
print(type(gbm_data))
print(gbm_data[:10,:])
print(gbm_data.shape)
# Out:
# <class 'numpy.ndarray'>
# [[ 1.          0.          0.49700901 ...,  0.          0.          0.        ]
#  [ 1.          0.36666667  0.60629148 ...,  0.          1.          0.        ]
#  [ 1.          0.0333      0.48012427 ...,  0.          0.          0.        ]
#  ...,
#  [ 1.          0.13333333  0.61005673 ...,  0.          0.          0.        ]
#  [ 1.          0.          0.77681636 ...,  0.          0.          0.        ]
#  [ 0.          0.1         0.76814957 ...,  0.          0.          0.        ]]
# (3751, 1777)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(gbm_data[:,1:], gbm_data[:,:1], test_size=0.8, random_state=241)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (750, 1776)
# (3001, 1776)
# (750, 1)
# (3001, 1)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import log_loss

for lr in [1]:#, 0.5, 0.3, 0.2, 0.1] :
    print("lr = ", lr)
    clf = GradientBoostingClassifier(n_estimators=250, verbose=True, random_state=241, learning_rate = lr)
    clf.fit(X_train, np.ravel(y_train))
    
    staged_dec_func_train = clf.staged_decision_function(X_train)
    #staged_pred_train = 1 / (1 + np.exp(np.multiply(-1, list(staged_dec_func_train))))
    #train_loss = log_loss(y_train ,staged_pred_train)
    #print("log loss on train:\n", train_loss)
    #staged_dec_func_test = clf.staged_decision_function(X_test)
    #staged_pred_test = 1 / (1 + np.exp(np.multiply(-1, staged_dec_func_test)))
    #test_loss = log_loss(y_test ,staged_pred_test)
    #print("log loss on test:\n", test_loss)
# Out:
# lr =  1
#       Iter       Train Loss   Remaining Time
#          1           1.0190           31.87s
#          2           0.9192           32.12s
#          3           0.8272           32.11s
#          4           0.7834           31.49s
#          5           0.7109           31.41s
#          6           0.6368           31.07s
#          7           0.5797           30.83s
#          8           0.5610           30.37s
#          9           0.5185           30.21s
#         10           0.4984           30.00s
#         20           0.1999           29.12s
#         30           0.1313           27.21s
#         40           0.0790           26.05s
#         50           0.0511           24.59s
#         60           0.0352           23.13s
#         70           0.0245           21.78s
#         80           0.0162           20.45s
#         90           0.0114           19.16s
#        100           0.0077           17.94s
#        200           0.0004            5.59s
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(test_loss, 'r', linewidth=2)
plt.plot(train_loss, 'g', linewidth=2)
plt.legend(['test', 'train'])

# %%
staged_dec_func_train = clf.staged_decision_function(X_train)

# %%
b = list(staged_dec_func_train)

# %%
len(b)
# Out:
# 250
