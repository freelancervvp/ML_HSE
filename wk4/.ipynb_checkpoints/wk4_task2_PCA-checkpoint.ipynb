# %%
import pandas as pd
import numpy as np
close_prices = pd.read_csv("close_prices.csv")#, header = None, names = ['y', 'x1', 'x2'])
print(close_prices.shape)
close_prices.head(10)
# Out:
# (374, 31)
#          date        AXP          BA        CAT       CSCO         CVX  \
# 0  2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 1  2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2  2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 3  2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 4  2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
# 5  2013-09-30  75.519997  117.500000  83.400002  23.430000  121.500000
# 6  2013-10-01  75.930000  117.750000  83.760002  23.240000  121.320000
# 7  2013-10-02  74.580002  117.839996  84.070000  23.320000  120.830002
# 8  2013-10-03  74.019997  115.239998  83.970001  23.010000  118.250000
# 9  2013-10-04  74.309998  117.199997  84.199997  23.020000  118.129997
#
#           DD        DIS         GE          GS    ...            PFE  \
# 0  59.409999  64.750000  24.280001  165.250000    ...      28.799999
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
pca.fit(close_prices.iloc[:, 1:])
# Out:
# PCA(copy=True, n_components=10, whiten=False)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [ 0.73897118  0.11007169  0.04995088  0.0287492   0.02215448  0.01931577
#   0.00674853  0.00614091  0.00320594  0.00305611]

# %%
print(pca.components_.shape)
print(pca.components_[0,:])

print(np.max(pca.components_[0,:]), np.argmax(pca.components_[0,:]), close_prices.columns[np.argmax(pca.components_[0,:])+1])
# Out:
# (10, 30)
# [  1.61383840e-02   1.20644923e-01  -5.16612711e-02   5.04842369e-02
#   -1.25859933e-01   1.14089567e-01   2.33906290e-01  -6.20513749e-03
#    2.51227032e-01   2.88996029e-01  -2.64998795e-01   9.31320168e-02
#    9.13948403e-02   4.69879340e-02   2.90549417e-02  -2.61068828e-02
#    3.29615584e-01   7.13897133e-02   7.62295699e-02   2.11888868e-01
#    2.30922941e-02   7.77316954e-02  -7.20594590e-03   1.89479745e-01
#    3.21564017e-01   5.36834873e-02   5.79683946e-01   1.09122230e-04
#    8.71614334e-02  -4.29421420e-02]
# 0.579683945747 26 V

# %%
close_prices_pca = pca.transform(close_prices.iloc[:, 1:])
print(close_prices_pca.shape)
print(close_prices_pca[:10,:1])
# Out:
# (374, 10)
# [[-50.90240358]
#  [-52.84690919]
#  [-54.61443917]
#  [-52.60056628]
#  [-52.3701233 ]
#  [-54.65341197]
#  [-52.81257496]
#  [-53.6511457 ]
#  [-56.69272698]
#  [-54.40265506]]

# %%
djia_index = pd.read_csv("djia_index.csv")#, header = None, names = ['y', 'x1', 'x2'])
print(djia_index.shape)
djia_index.head(10)
# Out:
# (374, 2)
#          date          ^DJI
# 0  2013-09-23  15401.379883
# 1  2013-09-24  15334.589844
# 2  2013-09-25  15273.259766
# 3  2013-09-26  15328.299805
# 4  2013-09-27  15258.240234
# 5  2013-09-30  15129.669922
# 6  2013-10-01  15191.700195
# 7  2013-10-02  15133.139648
# 8  2013-10-03  14996.480469
# 9  2013-10-04  15072.580078

# %%
print(close_prices_pca[:,0].shape)
print(djia_index['^DJI'].shape)
pearson = np.corrcoef(close_prices_pca[:,0], djia_index['^DJI'])
print(pearson)
# Out:
# (374,)
# (374,)
# [[ 1.          0.90965222]
#  [ 0.90965222  1.        ]]
